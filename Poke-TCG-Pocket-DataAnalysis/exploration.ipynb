# %%
import pandas as pd
# import json

# %%
df = pd.read_csv('pokemon-tcg.csv')
df.head(5)
# Out:
#     id  stage         name       from   hp   type ability a1cost  \
# 0  ga1      0    bulbasaur        NaN   70  grass     NaN     gx
# 1  ga2      1      ivysaur  bulbasaur   90  grass     NaN    gxx
# 2  ga3      2     venusaur    ivysaur  160  grass     NaN   ggxx
# 3  ga4      2  venusaur EX    ivysaur  190  grass     NaN    gxx
# 4  ga5      0     caterpie        NaN   50  grass     NaN      x
#
#           a1name  a1damage a1bonus  a1bonusDmg a2cost       a2name  a2damage  \
# 0      vine whip      40.0     NaN         NaN    NaN          NaN       NaN
# 1     razor leaf      60.0     NaN         NaN    NaN          NaN       NaN
# 2     mega drain      80.0    heal        30.0    NaN          NaN       NaN
# 3     razor leaf      60.0     NaN         NaN   ggxx  giant bloom     100.0
# 4  find a friend       NaN     NaN         NaN    NaN          NaN       NaN
#
#   a2bonus  a2bonusDmg weakness  retreat rarity
# 0     NaN         NaN     fire        1     1d
# 1     NaN         NaN     fire        2     2d
# 2     NaN         NaN     fire        3     3d
# 3    heal        30.0     fire        3     4d
# 4     NaN         NaN     fire        1     1d

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          565 non-null    object
#  1   stage       565 non-null    int64
#  2   name        565 non-null    object
#  3   from        262 non-null    object
#  4   hp          565 non-null    int64
#  5   type        565 non-null    object
#  6   ability     41 non-null     object
#  7   a1cost      565 non-null    object
#  8   a1name      565 non-null    object
#  9   a1damage    527 non-null    float64
#  10  a1bonus     207 non-null    object
#  11  a1bonusDmg  146 non-null    float64
#  12  a2cost      34 non-null     object
#  13  a2name      34 non-null     object
#  14  a2damage    30 non-null     float64
#  15  a2bonus     14 non-null     object
#  16  a2bonusDmg  14 non-null     float64
#  17  weakness    556 non-null    object
#  18  retreat     565 non-null    int64
#  19  rarity      565 non-null    object
# dtypes: float64(4), int64(3), object(13)
# memory usage: 88.4+ KB

# %%
weakness_colors = {
    'water': '#0000aa',
    'psychic': '#aa00aa',
    'metal': 'lightblue',
    'grass': '#00aa00',
    'fire': '#aa0000',
    'fighting': '#964b00',
    'electric': '#fff700',
    'dark': '#222244',
    'dragon': '#c0c0c0'
}

# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="Usti6W"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("Usti6W").appendChild(div);
#                     };
#                     var e = document.getElementById("Usti6W");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
(
    ggplot(
        df,
        aes(
            x='hp'
        )
    )
    + geom_histogram()
)
# Out:
#    <div id="u1QnSh"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("u1QnSh");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"hp"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"id"
# },{
# "type":"int",
# "column":"stage"
# },{
# "type":"str",
# "column":"name"
# },{
# "type":"str",
# "column":"from"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"str",
# "column":"type"
# },{
# "type":"str",
# "column":"ability"
# },{
# "type":"str",
# "column":"a1cost"
# },{
# "type":"str",
# "column":"a1name"
# },{
# "type":"float",
# "column":"a1damage"
# },{
# "type":"str",
# "column":"a1bonus"
# },{
# "type":"float",
# "column":"a1bonusDmg"
# },{
# "type":"str",
# "column":"a2cost"
# },{
# "type":"str",
# "column":"a2name"
# },{
# "type":"float",
# "column":"a2damage"
# },{
# "type":"str",
# "column":"a2bonus"
# },{
# "type":"float",
# "column":"a2bonusDmg"
# },{
# "type":"str",
# "column":"weakness"
# },{
# "type":"int",
# "column":"retreat"
# },{
# "type":"str",
# "column":"rarity"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"histogram",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..count..":[3.0,0.0,3.0,0.0,30.0,0.0,110.0,49.0,0.0,67.0,0.0,48.0,0.0,39.0,19.0,0.0,45.0,0.0,35.0,0.0,49.0,0.0,28.0,16.0,0.0,11.0,0.0,12.0,0.0,1.0],
# "hp":[29.057777777777776,34.64,40.22222222222222,45.80444444444444,51.38666666666667,56.968888888888884,62.55111111111111,68.13333333333334,73.71555555555555,79.29777777777778,84.88,90.46222222222222,96.04444444444445,101.62666666666667,107.2088888888889,112.7911111111111,118.37333333333333,123.95555555555556,129.5377777777778,135.12,140.70222222222222,146.28444444444446,151.86666666666667,157.4488888888889,163.03111111111113,168.61333333333334,174.19555555555556,179.77777777777777,185.36,190.94222222222223]
# }
# }],
# "metainfo_list":[],
# "spec_id":"68"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
type_health = df.groupby('type')['hp'].mean().round(2).reset_index().sort_values('hp', ascending=False)

type_health

(
    ggplot(
        type_health,
        aes(
            x='type',
            y='hp',
            fill='type'
        )
    )
    + geom_bar(stat='identity')
    + scale_fill_manual(values=weakness_colors)
    + labs(
        title='Average HP per Type',
        x='Type',
        y='HP',
        fill='Type'
    )
)
# Out:
#    <div id="CIsnLE"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("CIsnLE");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "type":["dragon","metal","fire","fighting","water","psychic","grass","dark","normal","electric"],
# "hp":[112.22,109.5,105.4,104.85,100.56,96.76,95.85,95.22,90.53,86.42]
# },
# "mapping":{
# "x":"type",
# "y":"hp",
# "fill":"type"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"type"
# },{
# "type":"float",
# "column":"hp"
# }]
# },
# "ggtitle":{
# "text":"Average HP per Type"
# },
# "guides":{
# "x":{
# "title":"Type"
# },
# "y":{
# "title":"HP"
# },
# "fill":{
# "title":"Type"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["water","psychic","metal","grass","fire","fighting","electric","dark","dragon"],
# "values":["#0000aa","#aa00aa","lightblue","#00aa00","#aa0000","#964b00","#fff700","#222244","#c0c0c0"]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"69"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
(
    ggplot(
        df,
        aes(
            x='stage',
        )
    )
    + geom_bar()
    + scale_x_discrete(breaks=[0, 1, 2], labels=['Basic', 'Stage 1', 'Stage 2'])
    + labs(
        title='Count of Cards per Stage',
        x='Stage',
        y='Count'
    )
)
# Out:
#    <div id="NnVtMn"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("NnVtMn");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"stage"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"id"
# },{
# "type":"int",
# "column":"stage"
# },{
# "type":"str",
# "column":"name"
# },{
# "type":"str",
# "column":"from"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"str",
# "column":"type"
# },{
# "type":"str",
# "column":"ability"
# },{
# "type":"str",
# "column":"a1cost"
# },{
# "type":"str",
# "column":"a1name"
# },{
# "type":"float",
# "column":"a1damage"
# },{
# "type":"str",
# "column":"a1bonus"
# },{
# "type":"float",
# "column":"a1bonusDmg"
# },{
# "type":"str",
# "column":"a2cost"
# },{
# "type":"str",
# "column":"a2name"
# },{
# "type":"float",
# "column":"a2damage"
# },{
# "type":"str",
# "column":"a2bonus"
# },{
# "type":"float",
# "column":"a2bonusDmg"
# },{
# "type":"str",
# "column":"weakness"
# },{
# "type":"int",
# "column":"retreat"
# },{
# "type":"str",
# "column":"rarity"
# }]
# },
# "ggtitle":{
# "text":"Count of Cards per Stage"
# },
# "guides":{
# "x":{
# "title":"Stage"
# },
# "y":{
# "title":"Count"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "breaks":[0.0,1.0,2.0],
# "labels":["Basic","Stage 1","Stage 2"],
# "discrete":true,
# "reverse":false
# }],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..count..":[302.0,188.0,75.0],
# "stage":[0.0,1.0,2.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"70"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
pokemon_name_counts = df.groupby('name')['id'].count().reset_index().rename(columns={'id': 'count'}).sort_values('count', ascending=False)

(
    ggplot(
        pokemon_name_counts,
        aes(
            x='count',
        )
    )
    + geom_bar()
    + labs(
        title='Number of Pokemon with Duplicate Cards',
        x='Duplicates',
        y='# of Pokemon'
    )
)
# Out:
#    <div id="8gC0C6"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("8gC0C6");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"count"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"count"
# }]
# },
# "ggtitle":{
# "text":"Number of Pokemon with Duplicate Cards"
# },
# "guides":{
# "x":{
# "title":"Duplicates"
# },
# "y":{
# "title":"# of Pokemon"
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..count..":[1.0,1.0,7.0,31.0,94.0,244.0],
# "count":[7.0,5.0,4.0,3.0,2.0,1.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"71"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
(
    ggplot(
        df.groupby('weakness')['id'].count().reset_index().rename(columns={'id': 'count'}).sort_values('count', ascending=False),
        aes(
            x='weakness',
            y='count',
            fill='weakness'
        )
    )
    + geom_bar(stat='identity')
    + scale_fill_manual(values=weakness_colors)
    + labs(
        title='Total # of Cards with each Weakness',
        x='Weakness',
        y='Count',
        fill='Weakness'
    )
)
# Out:
#    <div id="KdrFoN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("KdrFoN");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "weakness":["fighting","electric","fire","dark","grass","water","psychic","metal"],
# "count":[134.0,122.0,96.0,59.0,51.0,45.0,26.0,23.0]
# },
# "mapping":{
# "x":"weakness",
# "y":"count",
# "fill":"weakness"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"weakness"
# },{
# "type":"int",
# "column":"count"
# }]
# },
# "ggtitle":{
# "text":"Total # of Cards with each Weakness"
# },
# "guides":{
# "x":{
# "title":"Weakness"
# },
# "y":{
# "title":"Count"
# },
# "fill":{
# "title":"Weakness"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["water","psychic","metal","grass","fire","fighting","electric","dark","dragon"],
# "values":["#0000aa","#aa00aa","lightblue","#00aa00","#aa0000","#964b00","#fff700","#222244","#c0c0c0"]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"72"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
weakness_percents = (df.groupby('type')['weakness'].value_counts() / df.groupby('type')['weakness'].count() * 100).round(2).reset_index().rename(columns={0: 'percent'}).sort_values('weakness', ascending=False)

(
    ggplot(
        weakness_percents,
        aes(
            x='type',
            y='percent',
        )
    )
    + geom_bar(
        aes(
            fill='weakness',
        ),
        stat='identity',
        size=2
    )
    + scale_fill_manual(values=weakness_colors)
    + scale_color_manual(values=weakness_colors)
    + labs(
        title='Pokemon Weakness by Type',
        x='Type',
        y='% Weakness',
        fill='Weakness',
    )
)
# Out:
#    <div id="lRIIN5"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("lRIIN5");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "type":["fire","fighting","water","psychic","dark","fighting","metal","grass","electric","normal","dark","fighting","fire","electric","grass","metal","normal","dark","psychic","water","psychic"],
# "weakness":["water","psychic","metal","metal","grass","grass","fire","fire","fighting","fighting","fighting","electric","electric","electric","electric","electric","electric","electric","electric","electric","dark"],
# "percent":[90.0,39.39,12.36,16.22,30.43,56.06,90.0,95.12,92.45,72.37,65.22,4.55,10.0,7.55,4.88,10.0,27.63,4.35,4.05,87.64,79.73]
# },
# "mapping":{
# "x":"type",
# "y":"percent"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"type"
# },{
# "type":"str",
# "column":"weakness"
# },{
# "type":"float",
# "column":"percent"
# }]
# },
# "ggtitle":{
# "text":"Pokemon Weakness by Type"
# },
# "guides":{
# "x":{
# "title":"Type"
# },
# "y":{
# "title":"% Weakness"
# },
# "fill":{
# "title":"Weakness"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["water","psychic","metal","grass","fire","fighting","electric","dark","dragon"],
# "values":["#0000aa","#aa00aa","lightblue","#00aa00","#aa0000","#964b00","#fff700","#222244","#c0c0c0"]
# },{
# "aesthetic":"color",
# "breaks":["water","psychic","metal","grass","fire","fighting","electric","dark","dragon"],
# "values":["#0000aa","#aa00aa","lightblue","#00aa00","#aa0000","#964b00","#fff700","#222244","#c0c0c0"]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "fill":"weakness"
# },
# "data_meta":{
# },
# "size":2.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"73"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
weakness_counts = df.groupby('type')['weakness'].value_counts().reset_index().drop('count', axis=1).groupby('weakness').count().reset_index().rename(columns={'type': 'count'}).sort_values('count', ascending=False)

(
    ggplot(
        weakness_counts,
        aes(
            x='weakness',
            y='count',
            fill='weakness'
        )
    )
    + geom_bar(stat='identity')
    + scale_fill_manual(values=weakness_colors)
    + labs(
        title='Counts of Types Containing each Weakness',
        x='Weakness',
        y='Count',
        fill='Weakness'
    )
)
# Out:
#    <div id="qnYhoA"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("qnYhoA");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "weakness":["electric","fighting","fire","grass","metal","dark","psychic","water"],
# "count":[9.0,3.0,2.0,2.0,2.0,1.0,1.0,1.0]
# },
# "mapping":{
# "x":"weakness",
# "y":"count",
# "fill":"weakness"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"weakness"
# },{
# "type":"int",
# "column":"count"
# }]
# },
# "ggtitle":{
# "text":"Counts of Types Containing each Weakness"
# },
# "guides":{
# "x":{
# "title":"Weakness"
# },
# "y":{
# "title":"Count"
# },
# "fill":{
# "title":"Weakness"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["water","psychic","metal","grass","fire","fighting","electric","dark","dragon"],
# "values":["#0000aa","#aa00aa","lightblue","#00aa00","#aa0000","#964b00","#fff700","#222244","#c0c0c0"]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"74"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
